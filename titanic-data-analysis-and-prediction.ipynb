# %% [markdown]
# <a id='Environment_Setup'></a>
#
# # Environment Setup

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import plot_confusion_matrix

from sklearn.preprocessing import StandardScaler
from catboost import CatBoostClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier

# %% [markdown]
# <a id='Constants'></a>
# ## Constants

# %%
TRAIN_PATH = "train.csv"
TEST_PATH = "test.csv"

# %% [markdown]
# <a id='Functions'></a>
# ## Functions

# %%
def replace_titles(x):
    title=x['Title']
    if title in ['Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
        return 'Mr'
    elif title in ['Countess', 'Mme']:
        return 'Mrs'
    elif title in ['Mlle', 'Ms']:
        return 'Miss'
    elif title =='Dr':
        if x['Sex']=='Male':
            return 'Mr'
        else:
            return 'Mrs'
    else:
        return title
    
def substrings_in_string(big_string, substrings):
    for substring in substrings:
        if str.find(big_string, substring) != -1:
            return substring
    print (big_string)
    return np.nan

# %% [markdown]
# <a id='Data_Reading'></a>
#
# # Data Reading

# %%
train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# <a id='Data Expolration'></a>
# <html>
# <body>
#     <div style="background-color:rgba(187,126,140, 0.2); border-radius: 5px;">
#         <h1 style="color:#4E5166; padding:15px;">1. Data Expolration</h1>
#     </div>
# </body>
# </html>

# %% [markdown]
# <a id='Data_Cleaning'></a>
# ## 1.1. Data Cleaning

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print('\x1b[1;03;8;46m' + "Number of duplicated Records in train: " +  str(sum(train.duplicated())))
# Out:
# Number of duplicated Records in train: 0

# %%
train['PassengerId'] = train['PassengerId'].apply(str)

# %%
train.dropna(subset='Embarked', inplace=True)
train['Cabin'].fillna('Unknown', inplace = True)

# %%
train.loc[train['Age'] <1, 'Age'] = 0
train['Age'].fillna(0, inplace = True)

# %%
temp = train['Name'].apply(lambda x: x.split(','))
train['LastName'] = temp.apply(lambda x: x[0])
temp = temp.apply(lambda x: x[1].split('.'))
train['FirstName'] = temp.apply(lambda x: x[1][1:])
train['Title'] = temp.apply(lambda x: x[0][1:])
train.drop(columns=['Name'], inplace = True)

# %%
train['Title']= train.apply(replace_titles, axis=1)

# %%
cabin_list = ['A', 'B', 'C', 'D', 'E', 'F', 'T', 'G', 'Unknown']
train['Deck']=train['Cabin'].map(lambda x: substrings_in_string(x, cabin_list))

# %%
train['FamilySize']=train['SibSp']+train['Parch']

# %% [markdown]
# ## 1.2. Descriptive Analysis

# %%
train.drop(columns='Survived').describe().T
# Out:
#             count       mean        std  min     25%      50%   75%       max
# Pclass      889.0   2.311586   0.834700  1.0  2.0000   3.0000   3.0    3.0000
# Age         889.0  23.734533  17.570349  0.0  6.0000  24.0000  35.0   80.0000
# SibSp       889.0   0.524184   1.103705  0.0  0.0000   0.0000   1.0    8.0000
# Parch       889.0   0.382452   0.806761  0.0  0.0000   0.0000   0.0    6.0000
# Fare        889.0  32.096681  49.697504  0.0  7.8958  14.4542  31.0  512.3292
# FamilySize  889.0   0.906637   1.614703  0.0  0.0000   0.0000   1.0   10.0000

# %%
pd.DataFrame(train['Age'].mask(train['Age'] == 0).describe()).T
# Out:
#      count       mean        std  min   25%   50%   75%   max
# Age  705.0  29.929078  14.273901  1.0  21.0  28.0  38.0  80.0

# %%
plt.figure(figsize=(5,5))
sns.heatmap(train.corr(),cmap = 'viridis',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1.0, 'Variable Correlation')

# %% [markdown]
# > - It is clear that Far and Pclass have a negative and meaningful correlation
# > - A high correlation between Family size and Parch and Sibsp can be observed since they developed from Parch and Sibsp. As a result, Sibsp and Parch will be removed from the data

# %%
plt.figure(figsize=(5,5))
sns.heatmap(train.mask(train['Age'] == 0)[['Age','Survived']].corr(),cmap = 'viridis',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1.0, 'Variable Correlation')

# %% [markdown]
# > Since Age included zero value, which is meaningful for this feature, these values were masked for more accurate correlations

# %%
# Frequency
stats_df = train \
.groupby('Fare') \
['Fare'] \
.agg('count') \
.pipe(pd.DataFrame) \
.rename(columns = {'Fare': 'frequency'})

# PDF
stats_df['pdf'] = stats_df['frequency'] / sum(stats_df['frequency'])

# CDF
stats_df['cdf'] = stats_df['pdf'].cumsum()
stats_df = stats_df.reset_index()
stats_df.head(3)
# Out:
#      Fare  frequency       pdf       cdf
# 0  0.0000         15  0.016873  0.016873
# 1  4.0125          1  0.001125  0.017998
# 2  5.0000          1  0.001125  0.019123

# %%
train.hist()
plt.tight_layout()

# %%
pd.DataFrame(train.groupby(['Fare','Ticket'])['Pclass'].apply(np.unique))
# Out:
#                   Pclass
# Fare     Ticket
# 0.0000   112050      [1]
#          112052      [1]
#          112058      [1]
#          112059      [1]
#          19972       [1]
# ...                  ...
# 227.5250 PC 17757    [1]
# 247.5208 PC 17558    [1]
# 262.3750 PC 17608    [1]
# 263.0000 19950       [1]
# 512.3292 PC 17755    [1]
#
# [681 rows x 1 columns]

# %% [markdown]
# > Because each ticket has a fare, "ticket" can be considered a duplicate feature and should be removed as it does not add any further information

# %%
train.drop(columns=['Parch', 'SibSp', 'Cabin', 'LastName', 'FirstName', 'Ticket'], inplace=True)
train.head(3)
# Out:
#   PassengerId  Survived  Pclass     Sex   Age     Fare Embarked Title  \
# 0           1         0       3    male  22.0   7.2500        S    Mr
# 1           2         1       1  female  38.0  71.2833        C   Mrs
# 2           3         1       3  female  26.0   7.9250        S  Miss
#
#       Deck  FamilySize
# 0  Unknown           1
# 1        C           1
# 2  Unknown           0

# %%
ax = train['Survived'].hist(color=(0.188,0.66,0.413))
ax.set_xlabel("Survived")
ax.set_ylabel("Number of passenger")
plt.show()

# %%
bins = np.arange(2) - 0.5
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20, 25))
train.groupby('Pclass').count()['Survived'].plot(kind='bar', ax=axes[0,0], color=(0.188,0.66,0.413)) 
train.groupby('Sex').count()['Survived'].plot(kind='bar', ax=axes[0,1], color=(0.5,0,0.8)) 
train.groupby('Embarked').count()['Survived'].plot(kind='bar', ax=axes[1,0], color=(1,0.9,0)) 
train.groupby('Deck').count()['Survived'].plot(kind='bar', ax=axes[1,1], color=(0.6,0.1,0)) 
train.groupby('FamilySize').count()['Survived'].plot(kind='bar', ax=axes[2,0], color=(0.9,0.2,0.9)) 
train.groupby('Title').count()['Survived'].plot(kind='bar', ax=axes[2,1], color=(0.3,0.1,0.9)) 
fig.suptitle('Number of survivor in diffrent categories', fontsize=16)
plt.show()

# %%
train['Age'] = train['Age'].apply(int)

# %%
plt.style.use("ggplot")
for column in ['Age', 'Fare']:
    plt.figure(figsize=(20,4))
    plt.subplot(121)
    sns.distplot(train[column], kde=True)
    plt.title(column)

# %%
plt.style.use("ggplot")
for column in ['Pclass', 'Sex', 'Age', 'Embarked', 'Title', 'FamilySize', 'Fare']:
    plt.figure(figsize=(60,10))
    plt.subplot(121)
    sns.countplot(train[column], hue=train["Survived"])
    plt.title(column)    
    plt.xticks(rotation=90)

# %% [markdown]
# <a id='Data Expolration'></a>
# <html>
# <body>
#     <div style="background-color:rgba(187,126,140, 0.2); border-radius: 5px;">
#         <h1 style="color:#4E5166; padding:15px;">2. model implementation</h1>
#     </div>
# </body>
# </html>

# %% [markdown]
# ## 2.1. Remove skewness

# %%
# Plot train distribution
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
sns.distplot(train['Age'], color=(0.188,0.66,0.413))

plt.subplot(1,2,2)
sns.distplot(train['Fare'], color=(0.5,0,0.8))
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
train_log = train.copy()
train_log['Age'] = train_log['Age'].map(lambda i: np.log(i) if i > 0 else 0)
train_log['Fare'] = train_log['Fare'].map(lambda i: np.log(i) if i > 0 else 0)

plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
sns.distplot(train_log['Age'], color=(0.188,0.66,0.413))

plt.subplot(1,2,2)
sns.distplot(train_log['Fare'], color=(0.5,0,0.8))
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %% [markdown]
# ## 2.2. Data Scaling

# %% [markdown]
# Do we need over/under/random sampling?

# %%
counter = dict(train_log['Survived'].value_counts())
print(counter)
print('The ratio of survived to not survived is:',round(counter[1]/counter[0]*100,2))
# Out:
# {0: 549, 1: 340}
# The ratio of survived to not survived is: 61.93

# %% [markdown]
# > Doesn't seem so

# %%
X = train_log.drop(columns=['Survived']).set_index('PassengerId')
Y = train_log[['PassengerId','Survived']].set_index('PassengerId')

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[["Age","Fare","FamilySize", "Pclass"]])
X_scaled = pd.DataFrame(X_scaled,columns=["Age","Fare","FamilySize","Pclass"], index=X.index)
X_scaled = X_scaled.join(X.drop(columns=["Age","Fare","FamilySize","Pclass"]))

# %% [markdown]
# ## 2.3. Prediction

# %% [markdown]
# ### 2.3.1. Catboost

# %% [markdown]
# #### Train phase

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=test_size, random_state=seed)

# %%
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# Survived
# 0           375
# 1           220
# dtype: int64
# Survived
# 0           174
# 1           120
# dtype: int64

# %%
X_train_enc = X_train.apply(LabelEncoder().fit_transform)
X_train_enc.head()
# Out:
#              Age  Fare  FamilySize  Pclass  Sex  Embarked  Title  Deck
# PassengerId
# 745           27    31           0       2    1         2      3     8
# 659           19    64           0       1    1         2      3     8
# 841           16    31           0       2    1         2      3     8
# 718           23    54           0       1    0         2      2     4
# 796           35    64           0       1    1         2      3     8

# %%
model = CatBoostClassifier(verbose=10)

grid = {'learning_rate': [0.03, 0.05, 0.1, 0.2, 0.5],
        'depth': [4, 6, 10, 16],
        'iterations': [5, 10, 15, 20, 50]}

grid_search_result = model.grid_search(grid, 
                                       X=X_train_enc, 
                                       y=y_train, 
                                       plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 143ms	remaining: 572ms
# 4:	learn: 0.6132778	test: 0.6184732	best: 0.6184732 (4)	total: 148ms	remaining: 0us
#
# bestTest = 0.6184732402
# bestIteration = 4
#
# 0:	loss: 0.6184732	best: 0.6184732 (0)	total: 170ms	remaining: 16.8s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.5ms	remaining: 6.01ms
# 4:	learn: 0.5703807	test: 0.5791741	best: 0.5791741 (4)	total: 6.89ms	remaining: 0us
#
# bestTest = 0.5791740877
# bestIteration = 4
#
# 1:	loss: 0.5791741	best: 0.5791741 (1)	total: 178ms	remaining: 8.74s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.5ms	remaining: 5.99ms
# 4:	learn: 0.4953498	test: 0.5114010	best: 0.5114010 (4)	total: 6.62ms	remaining: 0us
#
# bestTest = 0.5114009811
# bestIteration = 4
#
# 2:	loss: 0.5114010	best: 0.5114010 (2)	total: 186ms	remaining: 6.03s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.1ms	remaining: 8.39ms
# 4:	learn: 0.4241032	test: 0.4506145	best: 0.4506145 (4)	total: 9.76ms	remaining: 0us
#
# bestTest = 0.4506144519
# bestIteration = 4
#
# 3:	loss: 0.4506145	best: 0.4506145 (3)	total: 197ms	remaining: 4.74s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.9ms	remaining: 7.61ms
# 4:	learn: 0.3776161	test: 0.4353328	best: 0.4288333 (2)	total: 7.62ms	remaining: 0us
#
# bestTest = 0.4288333064
# bestIteration = 2
#
# 4:	loss: 0.4288333	best: 0.4288333 (4)	total: 206ms	remaining: 3.91s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.14ms	remaining: 10.3ms
# 9:	learn: 0.5575566	test: 0.5661033	best: 0.5661033 (9)	total: 12.7ms	remaining: 0us
#
# bestTest = 0.5661032689
# bestIteration = 9
#
# 5:	loss: 0.5661033	best: 0.4288333 (4)	total: 220ms	remaining: 3.44s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.03ms	remaining: 9.32ms
# 9:	learn: 0.5046877	test: 0.5185013	best: 0.5185013 (9)	total: 10ms	remaining: 0us
#
# bestTest = 0.5185012742
# bestIteration = 9
#
# 6:	loss: 0.5185013	best: 0.4288333 (4)	total: 231ms	remaining: 3.07s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.17ms	remaining: 10.6ms
# 9:	learn: 0.4314126	test: 0.4596624	best: 0.4596624 (9)	total: 13.4ms	remaining: 0us
#
# bestTest = 0.4596624281
# bestIteration = 9
#
# 7:	loss: 0.4596624	best: 0.4288333 (4)	total: 246ms	remaining: 2.83s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.11ms	remaining: 10ms
# 9:	learn: 0.3895466	test: 0.4391137	best: 0.4363961 (6)	total: 13.6ms	remaining: 0us
#
# bestTest = 0.4363960604
# bestIteration = 6
#
# 8:	loss: 0.4363961	best: 0.4288333 (4)	total: 261ms	remaining: 2.63s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.49ms	remaining: 13.4ms
# 9:	learn: 0.3455615	test: 0.4754700	best: 0.4288333 (2)	total: 15ms	remaining: 0us
#
# bestTest = 0.4288333064
# bestIteration = 2
#
# 9:	loss: 0.4288333	best: 0.4288333 (4)	total: 277ms	remaining: 2.49s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.77ms	remaining: 24.8ms
# 10:	learn: 0.5471825	test: 0.5566340	best: 0.5566340 (10)	total: 14.3ms	remaining: 5.2ms
# 14:	learn: 0.5130996	test: 0.5259847	best: 0.5259847 (14)	total: 21.1ms	remaining: 0us
#
# bestTest = 0.5259847204
# bestIteration = 14
#
# 10:	loss: 0.5259847	best: 0.4288333 (4)	total: 300ms	remaining: 2.42s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.69ms	remaining: 23.6ms
# 10:	learn: 0.4933392	test: 0.5084604	best: 0.5084604 (10)	total: 12.2ms	remaining: 4.45ms
# 14:	learn: 0.4626497	test: 0.4831180	best: 0.4831180 (14)	total: 16.2ms	remaining: 0us
#
# bestTest = 0.4831180435
# bestIteration = 14
#
# 11:	loss: 0.4831180	best: 0.4288333 (4)	total: 317ms	remaining: 2.33s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.24ms	remaining: 17.3ms
# 10:	learn: 0.4246184	test: 0.4564175	best: 0.4564175 (10)	total: 11.8ms	remaining: 4.29ms
# 14:	learn: 0.4033517	test: 0.4429487	best: 0.4429487 (14)	total: 16.8ms	remaining: 0us
#
# bestTest = 0.442948667
# bestIteration = 14
#
# 12:	loss: 0.4429487	best: 0.4288333 (4)	total: 335ms	remaining: 2.24s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.03ms	remaining: 14.5ms
# 10:	learn: 0.3839860	test: 0.4376132	best: 0.4363961 (6)	total: 11.3ms	remaining: 4.12ms
# 14:	learn: 0.3636157	test: 0.4260053	best: 0.4260053 (14)	total: 16ms	remaining: 0us
#
# bestTest = 0.4260052661
# bestIteration = 14
#
# 13:	loss: 0.4260053	best: 0.4260053 (13)	total: 352ms	remaining: 2.17s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.05ms	remaining: 14.7ms
# 10:	learn: 0.3438232	test: 0.4769766	best: 0.4288333 (2)	total: 12.8ms	remaining: 4.64ms
# 14:	learn: 0.3270826	test: 0.4892312	best: 0.4288333 (2)	total: 17.9ms	remaining: 0us
#
# bestTest = 0.4288333064
# bestIteration = 2
#
# 14:	loss: 0.4288333	best: 0.4260053 (13)	total: 372ms	remaining: 2.11s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.2ms	remaining: 22.7ms
# 10:	learn: 0.5471825	test: 0.5566340	best: 0.5566340 (10)	total: 11.9ms	remaining: 9.75ms
# 19:	learn: 0.4799880	test: 0.4979795	best: 0.4979795 (19)	total: 35.2ms	remaining: 0us
#
# bestTest = 0.4979794956
# bestIteration = 19
#
# 15:	loss: 0.4979795	best: 0.4260053 (13)	total: 409ms	remaining: 2.15s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.75ms	remaining: 33.2ms
# 10:	learn: 0.4933392	test: 0.5084604	best: 0.5084604 (10)	total: 14.4ms	remaining: 11.8ms
# 19:	learn: 0.4341400	test: 0.4580935	best: 0.4580935 (19)	total: 25.7ms	remaining: 0us
#
# bestTest = 0.4580934623
# bestIteration = 19
#
# 16:	loss: 0.4580935	best: 0.4260053 (13)	total: 436ms	remaining: 2.13s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.08ms	remaining: 20.4ms
# 10:	learn: 0.4246184	test: 0.4564175	best: 0.4564175 (10)	total: 18.5ms	remaining: 15.2ms
# 19:	learn: 0.3882808	test: 0.4409409	best: 0.4409409 (19)	total: 28.6ms	remaining: 0us
#
# bestTest = 0.4409408573
# bestIteration = 19
#
# 17:	loss: 0.4409409	best: 0.4260053 (13)	total: 466ms	remaining: 2.12s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.52ms	remaining: 29ms
# 10:	learn: 0.3839860	test: 0.4376132	best: 0.4363961 (6)	total: 14ms	remaining: 11.5ms
# 19:	learn: 0.3527115	test: 0.4348173	best: 0.4260053 (14)	total: 23.7ms	remaining: 0us
#
# bestTest = 0.4260052661
# bestIteration = 14
#
# 18:	loss: 0.4260053	best: 0.4260053 (13)	total: 492ms	remaining: 2.1s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.19ms	remaining: 22.6ms
# 10:	learn: 0.3438232	test: 0.4769766	best: 0.4288333 (2)	total: 12.2ms	remaining: 9.99ms
# 19:	learn: 0.2954939	test: 0.4958530	best: 0.4288333 (2)	total: 25ms	remaining: 0us
#
# bestTest = 0.4288333064
# bestIteration = 2
#
# 19:	loss: 0.4288333	best: 0.4260053 (13)	total: 518ms	remaining: 2.07s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.04ms	remaining: 50.8ms
# 10:	learn: 0.5471825	test: 0.5566340	best: 0.5566340 (10)	total: 13.3ms	remaining: 47.3ms
# 20:	learn: 0.4753919	test: 0.4931836	best: 0.4931836 (20)	total: 29.1ms	remaining: 40.1ms
# 30:	learn: 0.4378546	test: 0.4674377	best: 0.4674377 (30)	total: 39.8ms	remaining: 24.4ms
# 40:	learn: 0.4160442	test: 0.4560796	best: 0.4560796 (40)	total: 50.4ms	remaining: 11.1ms
# 49:	learn: 0.4036057	test: 0.4473253	best: 0.4473253 (49)	total: 64.6ms	remaining: 0us
#
# bestTest = 0.4473253252
# bestIteration = 49
#
# 20:	loss: 0.4473253	best: 0.4260053 (13)	total: 586ms	remaining: 2.2s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.1ms	remaining: 54.1ms
# 10:	learn: 0.4933392	test: 0.5084604	best: 0.5084604 (10)	total: 11.6ms	remaining: 41.1ms
# 20:	learn: 0.4297942	test: 0.4558440	best: 0.4558440 (20)	total: 25.4ms	remaining: 35.1ms
# 30:	learn: 0.3984537	test: 0.4414204	best: 0.4414204 (30)	total: 43.3ms	remaining: 26.6ms
# 40:	learn: 0.3841004	test: 0.4357932	best: 0.4351147 (38)	total: 54.3ms	remaining: 11.9ms
# 49:	learn: 0.3743032	test: 0.4368142	best: 0.4351147 (38)	total: 66ms	remaining: 0us
#
# bestTest = 0.4351146954
# bestIteration = 38
#
# 21:	loss: 0.4351147	best: 0.4260053 (13)	total: 654ms	remaining: 2.32s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.02ms	remaining: 98.8ms
# 10:	learn: 0.4246184	test: 0.4564175	best: 0.4564175 (10)	total: 19.2ms	remaining: 68ms
# 20:	learn: 0.3860321	test: 0.4428831	best: 0.4409409 (19)	total: 36.4ms	remaining: 50.3ms
# 30:	learn: 0.3666800	test: 0.4457396	best: 0.4409409 (19)	total: 51.4ms	remaining: 31.5ms
# 40:	learn: 0.3517998	test: 0.4543683	best: 0.4409409 (19)	total: 72.7ms	remaining: 16ms
# 49:	learn: 0.3414143	test: 0.4616213	best: 0.4409409 (19)	total: 89.7ms	remaining: 0us
#
# bestTest = 0.4409408573
# bestIteration = 19
#
# 22:	loss: 0.4409409	best: 0.4260053 (13)	total: 746ms	remaining: 2.5s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.18ms	remaining: 107ms
# 10:	learn: 0.3839860	test: 0.4376132	best: 0.4363961 (6)	total: 19.7ms	remaining: 70ms
# 20:	learn: 0.3481449	test: 0.4394720	best: 0.4260053 (14)	total: 35.4ms	remaining: 48.9ms
# 30:	learn: 0.3269242	test: 0.4603490	best: 0.4260053 (14)	total: 49.7ms	remaining: 30.5ms
# 40:	learn: 0.3108122	test: 0.4771157	best: 0.4260053 (14)	total: 61ms	remaining: 13.4ms
# 49:	learn: 0.2835259	test: 0.4742973	best: 0.4260053 (14)	total: 70.4ms	remaining: 0us
#
# bestTest = 0.4260052661
# bestIteration = 14
#
# 23:	loss: 0.4260053	best: 0.4260053 (13)	total: 820ms	remaining: 2.6s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.16ms	remaining: 57.1ms
# 10:	learn: 0.3438232	test: 0.4769766	best: 0.4288333 (2)	total: 14.7ms	remaining: 52ms
# 20:	learn: 0.2928753	test: 0.4939807	best: 0.4288333 (2)	total: 27.6ms	remaining: 38.2ms
# 30:	learn: 0.2319474	test: 0.5002519	best: 0.4288333 (2)	total: 42.3ms	remaining: 25.9ms
# 40:	learn: 0.2000557	test: 0.5366588	best: 0.4288333 (2)	total: 58.7ms	remaining: 12.9ms
# 49:	learn: 0.1710059	test: 0.5621373	best: 0.4288333 (2)	total: 73.2ms	remaining: 0us
#
# bestTest = 0.4288333064
# bestIteration = 2
#
# 24:	loss: 0.4288333	best: 0.4260053 (13)	total: 896ms	remaining: 2.69s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.36ms	remaining: 5.43ms
# 4:	learn: 0.6051786	test: 0.6116099	best: 0.6116099 (4)	total: 9.64ms	remaining: 0us
#
# bestTest = 0.6116099278
# bestIteration = 4
#
# 25:	loss: 0.6116099	best: 0.4260053 (13)	total: 906ms	remaining: 2.58s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 2.35ms	remaining: 9.39ms
# 4:	learn: 0.5616670	test: 0.5725742	best: 0.5725742 (4)	total: 11.2ms	remaining: 0us
#
# bestTest = 0.5725742492
# bestIteration = 4
#
# 26:	loss: 0.5725742	best: 0.4260053 (13)	total: 919ms	remaining: 2.48s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.31ms	remaining: 9.23ms
# 4:	learn: 0.4864642	test: 0.5063428	best: 0.5063428 (4)	total: 11.9ms	remaining: 0us
#
# bestTest = 0.5063428055
# bestIteration = 4
#
# 27:	loss: 0.5063428	best: 0.4260053 (13)	total: 932ms	remaining: 2.4s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.22ms	remaining: 4.88ms
# 4:	learn: 0.4060839	test: 0.4450541	best: 0.4450541 (4)	total: 9.09ms	remaining: 0us
#
# bestTest = 0.4450540879
# bestIteration = 4
#
# 28:	loss: 0.4450541	best: 0.4260053 (13)	total: 943ms	remaining: 2.31s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.32ms	remaining: 5.28ms
# 4:	learn: 0.3437939	test: 0.4321256	best: 0.4160750 (3)	total: 9.56ms	remaining: 0us
#
# bestTest = 0.4160750058
# bestIteration = 3
#
# 29:	loss: 0.4160750	best: 0.4160750 (29)	total: 953ms	remaining: 2.22s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.61ms	remaining: 14.5ms
# 9:	learn: 0.5503988	test: 0.5599115	best: 0.5599115 (9)	total: 19ms	remaining: 0us
#
# bestTest = 0.5599114799
# bestIteration = 9
#
# 30:	loss: 0.5599115	best: 0.4160750 (29)	total: 974ms	remaining: 2.17s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 2.53ms	remaining: 22.8ms
# 9:	learn: 0.4956422	test: 0.5113069	best: 0.5113069 (9)	total: 19.6ms	remaining: 0us
#
# bestTest = 0.5113069164
# bestIteration = 9
#
# 31:	loss: 0.5113069	best: 0.4160750 (29)	total: 995ms	remaining: 2.11s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.24ms	remaining: 11.2ms
# 9:	learn: 0.4118032	test: 0.4536082	best: 0.4536082 (9)	total: 17.4ms	remaining: 0us
#
# bestTest = 0.453608203
# bestIteration = 9
#
# 32:	loss: 0.4536082	best: 0.4160750 (29)	total: 1.01s	remaining: 2.06s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.43ms	remaining: 12.9ms
# 9:	learn: 0.3569486	test: 0.4267874	best: 0.4267874 (9)	total: 15.5ms	remaining: 0us
#
# bestTest = 0.4267873627
# bestIteration = 9
#
# 33:	loss: 0.4267874	best: 0.4160750 (29)	total: 1.03s	remaining: 2s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 2.59ms	remaining: 23.3ms
# 9:	learn: 0.3039515	test: 0.4609036	best: 0.4160750 (3)	total: 22.2ms	remaining: 0us
#
# bestTest = 0.4160750058
# bestIteration = 3
#
# 34:	loss: 0.4160750	best: 0.4160750 (29)	total: 1.05s	remaining: 1.96s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 2.22ms	remaining: 31.1ms
# 10:	learn: 0.5419519	test: 0.5512961	best: 0.5512961 (10)	total: 18.9ms	remaining: 6.89ms
# 14:	learn: 0.5047754	test: 0.5194066	best: 0.5194066 (14)	total: 27.3ms	remaining: 0us
#
# bestTest = 0.5194066154
# bestIteration = 14
#
# 35:	loss: 0.5194066	best: 0.4160750 (29)	total: 1.08s	remaining: 1.93s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 2.3ms	remaining: 32.2ms
# 10:	learn: 0.4821912	test: 0.4996144	best: 0.4996144 (10)	total: 22.1ms	remaining: 8.02ms
# 14:	learn: 0.4508918	test: 0.4746667	best: 0.4746667 (14)	total: 30ms	remaining: 0us
#
# bestTest = 0.4746667044
# bestIteration = 14
#
# 36:	loss: 0.4746667	best: 0.4160750 (29)	total: 1.11s	remaining: 1.9s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.33ms	remaining: 32.7ms
# 10:	learn: 0.4013718	test: 0.4456824	best: 0.4456824 (10)	total: 24.1ms	remaining: 8.76ms
# 14:	learn: 0.3783126	test: 0.4352708	best: 0.4352708 (14)	total: 31.9ms	remaining: 0us
#
# bestTest = 0.4352708063
# bestIteration = 14
#
# 37:	loss: 0.4352708	best: 0.4160750 (29)	total: 1.15s	remaining: 1.88s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.65ms	remaining: 37.1ms
# 10:	learn: 0.3527575	test: 0.4267525	best: 0.4267525 (10)	total: 25.2ms	remaining: 9.15ms
# 14:	learn: 0.3373545	test: 0.4295508	best: 0.4267525 (10)	total: 32.7ms	remaining: 0us
#
# bestTest = 0.4267524927
# bestIteration = 10
#
# 38:	loss: 0.4267525	best: 0.4160750 (29)	total: 1.18s	remaining: 1.85s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.88ms	remaining: 26.4ms
# 10:	learn: 0.2952177	test: 0.4602709	best: 0.4160750 (3)	total: 26.3ms	remaining: 9.57ms
# 14:	learn: 0.2748036	test: 0.4687663	best: 0.4160750 (3)	total: 34.3ms	remaining: 0us
#
# bestTest = 0.4160750058
# bestIteration = 3
#
# 39:	loss: 0.4160750	best: 0.4160750 (29)	total: 1.22s	remaining: 1.83s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.85ms	remaining: 35.1ms
# 10:	learn: 0.5419519	test: 0.5512961	best: 0.5512961 (10)	total: 15.4ms	remaining: 12.6ms
# 19:	learn: 0.4757295	test: 0.4941089	best: 0.4941089 (19)	total: 27.7ms	remaining: 0us
#
# bestTest = 0.4941089344
# bestIteration = 19
#
# 40:	loss: 0.4941089	best: 0.4160750 (29)	total: 1.25s	remaining: 1.8s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.39ms	remaining: 26.5ms
# 10:	learn: 0.4821912	test: 0.4996144	best: 0.4996144 (10)	total: 20.9ms	remaining: 17.1ms
# 19:	learn: 0.4189171	test: 0.4549242	best: 0.4549242 (19)	total: 39ms	remaining: 0us
#
# bestTest = 0.4549242132
# bestIteration = 19
#
# 41:	loss: 0.4549242	best: 0.4160750 (29)	total: 1.29s	remaining: 1.78s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.35ms	remaining: 25.6ms
# 10:	learn: 0.4013718	test: 0.4456824	best: 0.4456824 (10)	total: 22.5ms	remaining: 18.4ms
# 19:	learn: 0.3604836	test: 0.4357842	best: 0.4352708 (14)	total: 41.2ms	remaining: 0us
#
# bestTest = 0.4352708063
# bestIteration = 14
#
# 42:	loss: 0.4352708	best: 0.4160750 (29)	total: 1.33s	remaining: 1.77s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.39ms	remaining: 45.4ms
# 10:	learn: 0.3527575	test: 0.4267525	best: 0.4267525 (10)	total: 27ms	remaining: 22.1ms
# 19:	learn: 0.3199118	test: 0.4472082	best: 0.4267525 (10)	total: 45.5ms	remaining: 0us
#
# bestTest = 0.4267524927
# bestIteration = 10
#
# 43:	loss: 0.4267525	best: 0.4160750 (29)	total: 1.38s	remaining: 1.76s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 3.13ms	remaining: 59.5ms
# 10:	learn: 0.2952177	test: 0.4602709	best: 0.4160750 (3)	total: 21.7ms	remaining: 17.8ms
# 19:	learn: 0.2305712	test: 0.4859778	best: 0.4160750 (3)	total: 42.4ms	remaining: 0us
#
# bestTest = 0.4160750058
# bestIteration = 3
#
# 44:	loss: 0.4160750	best: 0.4160750 (29)	total: 1.43s	remaining: 1.74s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.25ms	remaining: 61.4ms
# 10:	learn: 0.5419519	test: 0.5512961	best: 0.5512961 (10)	total: 16ms	remaining: 56.8ms
# 20:	learn: 0.4702242	test: 0.4888335	best: 0.4888335 (20)	total: 29.3ms	remaining: 40.4ms
# 30:	learn: 0.4288330	test: 0.4582277	best: 0.4582277 (30)	total: 45.2ms	remaining: 27.7ms
# 40:	learn: 0.3998928	test: 0.4445754	best: 0.4445754 (40)	total: 68.6ms	remaining: 15.1ms
# 49:	learn: 0.3832819	test: 0.4373668	best: 0.4373668 (49)	total: 86.5ms	remaining: 0us
#
# bestTest = 0.4373667677
# bestIteration = 49
#
# 45:	loss: 0.4373668	best: 0.4160750 (29)	total: 1.51s	remaining: 1.78s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.46ms	remaining: 71.4ms
# 10:	learn: 0.4821912	test: 0.4996144	best: 0.4996144 (10)	total: 23.5ms	remaining: 83.3ms
# 20:	learn: 0.4130021	test: 0.4521637	best: 0.4521637 (20)	total: 45.7ms	remaining: 63.1ms
# 30:	learn: 0.3806216	test: 0.4331526	best: 0.4331526 (30)	total: 65.2ms	remaining: 40ms
# 40:	learn: 0.3610328	test: 0.4259934	best: 0.4259934 (40)	total: 90.5ms	remaining: 19.9ms
# 49:	learn: 0.3466777	test: 0.4285615	best: 0.4259934 (40)	total: 114ms	remaining: 0us
#
# bestTest = 0.4259933758
# bestIteration = 40
#
# 46:	loss: 0.4259934	best: 0.4160750 (29)	total: 1.63s	remaining: 1.84s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.86ms	remaining: 140ms
# 10:	learn: 0.4013718	test: 0.4456824	best: 0.4456824 (10)	total: 28.6ms	remaining: 102ms
# 20:	learn: 0.3567295	test: 0.4333158	best: 0.4333158 (20)	total: 51.3ms	remaining: 70.8ms
# 30:	learn: 0.3311784	test: 0.4284553	best: 0.4254730 (27)	total: 72ms	remaining: 44.1ms
# 40:	learn: 0.3116933	test: 0.4403250	best: 0.4254730 (27)	total: 88.4ms	remaining: 19.4ms
# 49:	learn: 0.2988198	test: 0.4436601	best: 0.4254730 (27)	total: 105ms	remaining: 0us
#
# bestTest = 0.4254730316
# bestIteration = 27
#
# 47:	loss: 0.4254730	best: 0.4160750 (29)	total: 1.74s	remaining: 1.89s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.19ms	remaining: 108ms
# 10:	learn: 0.3527575	test: 0.4267525	best: 0.4267525 (10)	total: 23.2ms	remaining: 82.4ms
# 20:	learn: 0.3173971	test: 0.4500353	best: 0.4267525 (10)	total: 48.6ms	remaining: 67.1ms
# 30:	learn: 0.2858851	test: 0.4661748	best: 0.4267525 (10)	total: 65.7ms	remaining: 40.3ms
# 40:	learn: 0.2472370	test: 0.4776144	best: 0.4267525 (10)	total: 86ms	remaining: 18.9ms
# 49:	learn: 0.2260542	test: 0.4841010	best: 0.4267525 (10)	total: 100ms	remaining: 0us
#
# bestTest = 0.4267524927
# bestIteration = 10
#
# 48:	loss: 0.4267525	best: 0.4160750 (29)	total: 1.84s	remaining: 1.92s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.31ms	remaining: 64.3ms
# 10:	learn: 0.2952177	test: 0.4602709	best: 0.4160750 (3)	total: 25.1ms	remaining: 88.9ms
# 20:	learn: 0.2193421	test: 0.4805761	best: 0.4160750 (3)	total: 39ms	remaining: 53.9ms
# 30:	learn: 0.1605800	test: 0.5274378	best: 0.4160750 (3)	total: 55.4ms	remaining: 33.9ms
# 40:	learn: 0.1239867	test: 0.5332764	best: 0.4160750 (3)	total: 72.1ms	remaining: 15.8ms
# 49:	learn: 0.1009459	test: 0.5553150	best: 0.4160750 (3)	total: 90.2ms	remaining: 0us
#
# bestTest = 0.4160750058
# bestIteration = 3
#
# 49:	loss: 0.4160750	best: 0.4160750 (29)	total: 1.94s	remaining: 1.94s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 2.19ms	remaining: 8.74ms
# 4:	learn: 0.6067557	test: 0.6117985	best: 0.6117985 (4)	total: 22.7ms	remaining: 0us
#
# bestTest = 0.6117985204
# bestIteration = 4
#
# 50:	loss: 0.6117985	best: 0.4160750 (29)	total: 1.96s	remaining: 1.88s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.96ms	remaining: 7.83ms
# 4:	learn: 0.5586730	test: 0.5757139	best: 0.5757139 (4)	total: 26.3ms	remaining: 0us
#
# bestTest = 0.5757138929
# bestIteration = 4
#
# 51:	loss: 0.5757139	best: 0.4160750 (29)	total: 1.99s	remaining: 1.84s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.07ms	remaining: 8.28ms
# 4:	learn: 0.4788250	test: 0.5084918	best: 0.5084918 (4)	total: 27.5ms	remaining: 0us
#
# bestTest = 0.508491783
# bestIteration = 4
#
# 52:	loss: 0.5084918	best: 0.4160750 (29)	total: 2.02s	remaining: 1.79s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.35ms	remaining: 5.42ms
# 4:	learn: 0.3884927	test: 0.4431683	best: 0.4431683 (4)	total: 37.2ms	remaining: 0us
#
# bestTest = 0.4431682866
# bestIteration = 4
#
# 53:	loss: 0.4431683	best: 0.4160750 (29)	total: 2.06s	remaining: 1.75s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 11.3ms	remaining: 45.3ms
# 4:	learn: 0.2785950	test: 0.4528695	best: 0.4339896 (2)	total: 47.3ms	remaining: 0us
#
# bestTest = 0.4339895923
# bestIteration = 2
#
# 54:	loss: 0.4339896	best: 0.4160750 (29)	total: 2.11s	remaining: 1.72s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 4.32ms	remaining: 38.9ms
# 9:	learn: 0.5420052	test: 0.5550979	best: 0.5550979 (9)	total: 57.7ms	remaining: 0us
#
# bestTest = 0.5550978712
# bestIteration = 9
#
# 55:	loss: 0.5550979	best: 0.4160750 (29)	total: 2.17s	remaining: 1.7s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.88ms	remaining: 16.9ms
# 9:	learn: 0.4837149	test: 0.5112660	best: 0.5112660 (9)	total: 57.5ms	remaining: 0us
#
# bestTest = 0.5112660305
# bestIteration = 9
#
# 56:	loss: 0.5112660	best: 0.4160750 (29)	total: 2.23s	remaining: 1.68s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.21ms	remaining: 19.9ms
# 9:	learn: 0.4017090	test: 0.4549409	best: 0.4549409 (9)	total: 48.7ms	remaining: 0us
#
# bestTest = 0.4549408544
# bestIteration = 9
#
# 57:	loss: 0.4549409	best: 0.4160750 (29)	total: 2.28s	remaining: 1.65s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.46ms	remaining: 22.1ms
# 9:	learn: 0.3298876	test: 0.4301381	best: 0.4280405 (8)	total: 65.5ms	remaining: 0us
#
# bestTest = 0.4280404704
# bestIteration = 8
#
# 58:	loss: 0.4280405	best: 0.4160750 (29)	total: 2.34s	remaining: 1.63s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.69ms	remaining: 15.2ms
# 9:	learn: 0.2185164	test: 0.4471870	best: 0.4339896 (2)	total: 79.6ms	remaining: 0us
#
# bestTest = 0.4339895923
# bestIteration = 2
#
# 59:	loss: 0.4339896	best: 0.4160750 (29)	total: 2.43s	remaining: 1.62s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.78ms	remaining: 24.9ms
# 10:	learn: 0.5307074	test: 0.5465316	best: 0.5465316 (10)	total: 61.6ms	remaining: 22.4ms
# 14:	learn: 0.4932223	test: 0.5175652	best: 0.5175652 (14)	total: 84.9ms	remaining: 0us
#
# bestTest = 0.5175651947
# bestIteration = 14
#
# 60:	loss: 0.5175652	best: 0.4160750 (29)	total: 2.51s	remaining: 1.61s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.07ms	remaining: 15ms
# 10:	learn: 0.4688683	test: 0.5038418	best: 0.5038418 (10)	total: 70.5ms	remaining: 25.7ms
# 14:	learn: 0.4284399	test: 0.4755704	best: 0.4755704 (14)	total: 101ms	remaining: 0us
#
# bestTest = 0.4755704242
# bestIteration = 14
#
# 61:	loss: 0.4755704	best: 0.4160750 (29)	total: 2.62s	remaining: 1.6s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.73ms	remaining: 24.3ms
# 10:	learn: 0.3859802	test: 0.4512262	best: 0.4512262 (10)	total: 71.9ms	remaining: 26.2ms
# 14:	learn: 0.3505748	test: 0.4410091	best: 0.4410091 (14)	total: 120ms	remaining: 0us
#
# bestTest = 0.4410091237
# bestIteration = 14
#
# 62:	loss: 0.4410091	best: 0.4160750 (29)	total: 2.74s	remaining: 1.61s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.26ms	remaining: 17.7ms
# 10:	learn: 0.3289605	test: 0.4313549	best: 0.4280405 (8)	total: 61.8ms	remaining: 22.5ms
# 14:	learn: 0.2924409	test: 0.4384809	best: 0.4280405 (8)	total: 104ms	remaining: 0us
#
# bestTest = 0.4280404704
# bestIteration = 8
#
# 63:	loss: 0.4280405	best: 0.4160750 (29)	total: 2.84s	remaining: 1.6s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.67ms	remaining: 23.4ms
# 10:	learn: 0.2150799	test: 0.4623235	best: 0.4339896 (2)	total: 113ms	remaining: 41.1ms
# 14:	learn: 0.1868590	test: 0.4845302	best: 0.4339896 (2)	total: 168ms	remaining: 0us
#
# bestTest = 0.4339895923
# bestIteration = 2
#
# 64:	loss: 0.4339896	best: 0.4160750 (29)	total: 3.02s	remaining: 1.62s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.18ms	remaining: 22.4ms
# 10:	learn: 0.5307074	test: 0.5465316	best: 0.5465316 (10)	total: 71.8ms	remaining: 58.8ms
# 19:	learn: 0.4570452	test: 0.4878436	best: 0.4878436 (19)	total: 160ms	remaining: 0us
#
# bestTest = 0.4878435897
# bestIteration = 19
#
# 65:	loss: 0.4878436	best: 0.4160750 (29)	total: 3.18s	remaining: 1.64s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 2.78ms	remaining: 52.8ms
# 10:	learn: 0.4688683	test: 0.5038418	best: 0.5038418 (10)	total: 105ms	remaining: 86.2ms
# 19:	learn: 0.3938774	test: 0.4519084	best: 0.4519084 (19)	total: 194ms	remaining: 0us
#
# bestTest = 0.4519084318
# bestIteration = 19
#
# 66:	loss: 0.4519084	best: 0.4160750 (29)	total: 3.38s	remaining: 1.66s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 3.2ms	remaining: 60.8ms
# 10:	learn: 0.3859802	test: 0.4512262	best: 0.4512262 (10)	total: 94.1ms	remaining: 77ms
# 19:	learn: 0.3274368	test: 0.4332661	best: 0.4332661 (19)	total: 172ms	remaining: 0us
#
# bestTest = 0.4332660801
# bestIteration = 19
#
# 67:	loss: 0.4332661	best: 0.4160750 (29)	total: 3.55s	remaining: 1.67s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.67ms	remaining: 31.7ms
# 10:	learn: 0.3289605	test: 0.4313549	best: 0.4280405 (8)	total: 75ms	remaining: 61.4ms
# 19:	learn: 0.2691458	test: 0.4413991	best: 0.4280405 (8)	total: 166ms	remaining: 0us
#
# bestTest = 0.4280404704
# bestIteration = 8
#
# 68:	loss: 0.4280405	best: 0.4160750 (29)	total: 3.72s	remaining: 1.67s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 2.7ms	remaining: 51.3ms
# 10:	learn: 0.2150799	test: 0.4623235	best: 0.4339896 (2)	total: 112ms	remaining: 91.4ms
# 19:	learn: 0.1600938	test: 0.4814168	best: 0.4339896 (2)	total: 183ms	remaining: 0us
#
# bestTest = 0.4339895923
# bestIteration = 2
#
# 69:	loss: 0.4339896	best: 0.4160750 (29)	total: 3.91s	remaining: 1.68s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 2.15ms	remaining: 105ms
# 10:	learn: 0.5307074	test: 0.5465316	best: 0.5465316 (10)	total: 72.6ms	remaining: 257ms
# 20:	learn: 0.4506631	test: 0.4837361	best: 0.4837361 (20)	total: 140ms	remaining: 193ms
# 30:	learn: 0.4149390	test: 0.4555838	best: 0.4555838 (30)	total: 172ms	remaining: 105ms
# 40:	learn: 0.3824780	test: 0.4421129	best: 0.4421129 (40)	total: 253ms	remaining: 55.5ms
# 49:	learn: 0.3635418	test: 0.4327536	best: 0.4327536 (49)	total: 318ms	remaining: 0us
#
# bestTest = 0.4327536011
# bestIteration = 49
#
# 70:	loss: 0.4327536	best: 0.4160750 (29)	total: 4.23s	remaining: 1.73s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 2.6ms	remaining: 128ms
# 10:	learn: 0.4688683	test: 0.5038418	best: 0.5038418 (10)	total: 96.4ms	remaining: 342ms
# 20:	learn: 0.3886464	test: 0.4503180	best: 0.4503180 (20)	total: 203ms	remaining: 280ms
# 30:	learn: 0.3542048	test: 0.4347373	best: 0.4347373 (30)	total: 271ms	remaining: 166ms
# 40:	learn: 0.3331449	test: 0.4313395	best: 0.4313395 (40)	total: 327ms	remaining: 71.7ms
# 49:	learn: 0.3151710	test: 0.4307700	best: 0.4282710 (42)	total: 385ms	remaining: 0us
#
# bestTest = 0.4282709582
# bestIteration = 42
#
# 71:	loss: 0.4282710	best: 0.4160750 (29)	total: 4.62s	remaining: 1.8s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.72ms	remaining: 133ms
# 10:	learn: 0.3859802	test: 0.4512262	best: 0.4512262 (10)	total: 97.2ms	remaining: 345ms
# 20:	learn: 0.3205798	test: 0.4336377	best: 0.4332661 (19)	total: 188ms	remaining: 259ms
# 30:	learn: 0.2846376	test: 0.4405060	best: 0.4319440 (21)	total: 298ms	remaining: 183ms
# 40:	learn: 0.2586386	test: 0.4557836	best: 0.4319440 (21)	total: 460ms	remaining: 101ms
# 49:	learn: 0.2408344	test: 0.4610751	best: 0.4319440 (21)	total: 542ms	remaining: 0us
#
# bestTest = 0.4319440122
# bestIteration = 21
#
# 72:	loss: 0.4319440	best: 0.4160750 (29)	total: 5.17s	remaining: 1.91s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.85ms	remaining: 139ms
# 10:	learn: 0.3289605	test: 0.4313549	best: 0.4280405 (8)	total: 104ms	remaining: 368ms
# 20:	learn: 0.2657613	test: 0.4469343	best: 0.4280405 (8)	total: 218ms	remaining: 301ms
# 30:	learn: 0.2145947	test: 0.4641475	best: 0.4280405 (8)	total: 290ms	remaining: 178ms
# 40:	learn: 0.1722361	test: 0.4786732	best: 0.4280405 (8)	total: 400ms	remaining: 87.9ms
# 49:	learn: 0.1475521	test: 0.4957465	best: 0.4280405 (8)	total: 505ms	remaining: 0us
#
# bestTest = 0.4280404704
# bestIteration = 8
#
# 73:	loss: 0.4280405	best: 0.4160750 (29)	total: 5.68s	remaining: 2s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 3.28ms	remaining: 161ms
# 10:	learn: 0.2150799	test: 0.4623235	best: 0.4339896 (2)	total: 86.5ms	remaining: 307ms
# 20:	learn: 0.1565739	test: 0.4854605	best: 0.4339896 (2)	total: 193ms	remaining: 266ms
# 30:	learn: 0.0867005	test: 0.5345461	best: 0.4339896 (2)	total: 299ms	remaining: 184ms
# 40:	learn: 0.0601109	test: 0.5697153	best: 0.4339896 (2)	total: 410ms	remaining: 90ms
# 49:	learn: 0.0479127	test: 0.5840960	best: 0.4339896 (2)	total: 497ms	remaining: 0us
#
# bestTest = 0.4339895923
# bestIteration = 2
#
# 74:	loss: 0.4339896	best: 0.4160750 (29)	total: 6.19s	remaining: 2.06s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.06ms	remaining: 4.24ms
# 4:	learn: 0.6067557	test: 0.6117985	best: 0.6117985 (4)	total: 26.7ms	remaining: 0us
#
# bestTest = 0.6117985204
# bestIteration = 4
#
# 75:	loss: 0.6117985	best: 0.4160750 (29)	total: 6.22s	remaining: 1.96s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 2.21ms	remaining: 8.85ms
# 4:	learn: 0.5567789	test: 0.5736165	best: 0.5736165 (4)	total: 108ms	remaining: 0us
#
# bestTest = 0.5736164812
# bestIteration = 4
#
# 76:	loss: 0.5736165	best: 0.4160750 (29)	total: 6.33s	remaining: 1.89s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.46ms	remaining: 5.84ms
# 4:	learn: 0.4735881	test: 0.5035644	best: 0.5035644 (4)	total: 94ms	remaining: 0us
#
# bestTest = 0.5035643933
# bestIteration = 4
#
# 77:	loss: 0.5035644	best: 0.4160750 (29)	total: 6.42s	remaining: 1.81s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.96ms	remaining: 7.83ms
# 4:	learn: 0.3742964	test: 0.4584376	best: 0.4584376 (4)	total: 556ms	remaining: 0us
#
# bestTest = 0.4584376178
# bestIteration = 4
#
# 78:	loss: 0.4584376	best: 0.4160750 (29)	total: 6.98s	remaining: 1.85s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.6ms	remaining: 6.39ms
# 4:	learn: 0.2475222	test: 0.4607609	best: 0.4514902 (2)	total: 1.13s	remaining: 0us
#
# bestTest = 0.451490244
# bestIteration = 2
#
# 79:	loss: 0.4514902	best: 0.4160750 (29)	total: 8.11s	remaining: 2.03s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.52ms	remaining: 13.7ms
# 9:	learn: 0.5420052	test: 0.5550979	best: 0.5550979 (9)	total: 42ms	remaining: 0us
#
# bestTest = 0.5550978712
# bestIteration = 9
#
# 80:	loss: 0.5550979	best: 0.4160750 (29)	total: 8.15s	remaining: 1.91s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.31ms	remaining: 11.8ms
# 9:	learn: 0.4758782	test: 0.5062584	best: 0.5062584 (9)	total: 239ms	remaining: 0us
#
# bestTest = 0.5062584237
# bestIteration = 9
#
# 81:	loss: 0.5062584	best: 0.4160750 (29)	total: 8.39s	remaining: 1.84s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.33ms	remaining: 21ms
# 9:	learn: 0.3775129	test: 0.4464489	best: 0.4464489 (9)	total: 735ms	remaining: 0us
#
# bestTest = 0.4464488847
# bestIteration = 9
#
# 82:	loss: 0.4464489	best: 0.4160750 (29)	total: 9.13s	remaining: 1.87s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.53ms	remaining: 13.8ms
# 9:	learn: 0.3074405	test: 0.4390861	best: 0.4361813 (8)	total: 1.1s	remaining: 0us
#
# bestTest = 0.4361813108
# bestIteration = 8
#
# 83:	loss: 0.4361813	best: 0.4160750 (29)	total: 10.2s	remaining: 1.95s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.04ms	remaining: 9.37ms
# 9:	learn: 0.1918247	test: 0.4804546	best: 0.4514902 (2)	total: 1.5s	remaining: 0us
#
# bestTest = 0.451490244
# bestIteration = 2
#
# 84:	loss: 0.4514902	best: 0.4160750 (29)	total: 11.7s	remaining: 2.07s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.45ms	remaining: 20.4ms
# 10:	learn: 0.5308676	test: 0.5466943	best: 0.5466943 (10)	total: 62ms	remaining: 22.6ms
# 14:	learn: 0.4892256	test: 0.5198254	best: 0.5198254 (14)	total: 740ms	remaining: 0us
#
# bestTest = 0.5198253637
# bestIteration = 14
#
# 85:	loss: 0.5198254	best: 0.4160750 (29)	total: 12.5s	remaining: 2.03s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.71ms	remaining: 24ms
# 10:	learn: 0.4628001	test: 0.4987130	best: 0.4987130 (10)	total: 407ms	remaining: 148ms
# 14:	learn: 0.4187946	test: 0.4722162	best: 0.4722162 (14)	total: 566ms	remaining: 0us
#
# bestTest = 0.4722162335
# bestIteration = 14
#
# 86:	loss: 0.4722162	best: 0.4160750 (29)	total: 13.1s	remaining: 1.95s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.5ms	remaining: 35ms
# 10:	learn: 0.3663525	test: 0.4427455	best: 0.4427455 (10)	total: 811ms	remaining: 295ms
# 14:	learn: 0.3354572	test: 0.4354822	best: 0.4354822 (14)	total: 906ms	remaining: 0us
#
# bestTest = 0.4354821673
# bestIteration = 14
#
# 87:	loss: 0.4354822	best: 0.4160750 (29)	total: 14s	remaining: 1.9s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.25ms	remaining: 17.4ms
# 10:	learn: 0.2930474	test: 0.4365028	best: 0.4361813 (8)	total: 1.72s	remaining: 626ms
# 14:	learn: 0.2641687	test: 0.4399884	best: 0.4361813 (8)	total: 2.36s	remaining: 0us
#
# bestTest = 0.4361813108
# bestIteration = 8
#
# 88:	loss: 0.4361813	best: 0.4160750 (29)	total: 16.3s	remaining: 2.02s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.39ms	remaining: 19.5ms
# 10:	learn: 0.1787135	test: 0.4883578	best: 0.4514902 (2)	total: 2.07s	remaining: 754ms
# 14:	learn: 0.1314941	test: 0.5045140	best: 0.4514902 (2)	total: 3.69s	remaining: 0us
#
# bestTest = 0.451490244
# bestIteration = 2
#
# 89:	loss: 0.4514902	best: 0.4160750 (29)	total: 20s	remaining: 2.22s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 2.63ms	remaining: 50ms
# 10:	learn: 0.5308676	test: 0.5466943	best: 0.5466943 (10)	total: 73.7ms	remaining: 60.3ms
# 19:	learn: 0.4506199	test: 0.4955385	best: 0.4955385 (19)	total: 1.26s	remaining: 0us
#
# bestTest = 0.4955384633
# bestIteration = 19
#
# 90:	loss: 0.4955385	best: 0.4160750 (29)	total: 21.3s	remaining: 2.1s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.97ms	remaining: 37.5ms
# 10:	learn: 0.4628001	test: 0.4987130	best: 0.4987130 (10)	total: 315ms	remaining: 257ms
# 19:	learn: 0.3859974	test: 0.4505466	best: 0.4505466 (19)	total: 1.02s	remaining: 0us
#
# bestTest = 0.4505465945
# bestIteration = 19
#
# 91:	loss: 0.4505466	best: 0.4160750 (29)	total: 22.3s	remaining: 1.94s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 1.13ms	remaining: 21.5ms
# 10:	learn: 0.3663525	test: 0.4427455	best: 0.4427455 (10)	total: 745ms	remaining: 610ms
# 19:	learn: 0.3029945	test: 0.4380069	best: 0.4354822 (14)	total: 1.07s	remaining: 0us
#
# bestTest = 0.4354821673
# bestIteration = 14
#
# 92:	loss: 0.4354822	best: 0.4160750 (29)	total: 23.4s	remaining: 1.76s
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 1.22ms	remaining: 23.3ms
# 10:	learn: 0.2930474	test: 0.4365028	best: 0.4361813 (8)	total: 1.72s	remaining: 1.4s
# 19:	learn: 0.2371002	test: 0.4507192	best: 0.4361813 (8)	total: 3.04s	remaining: 0us
#
# bestTest = 0.4361813108
# bestIteration = 8
#
# 93:	loss: 0.4361813	best: 0.4160750 (29)	total: 26.4s	remaining: 1.69s
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 2.57ms	remaining: 48.8ms
# 10:	learn: 0.1787135	test: 0.4883578	best: 0.4514902 (2)	total: 1.96s	remaining: 1.6s
# 19:	learn: 0.0875564	test: 0.5077511	best: 0.4514902 (2)	total: 5.66s	remaining: 0us
#
# bestTest = 0.451490244
# bestIteration = 2
#
# 94:	loss: 0.4514902	best: 0.4160750 (29)	total: 32.1s	remaining: 1.69s
# 0:	learn: 0.6748447	test: 0.6758063	best: 0.6758063 (0)	total: 1.44ms	remaining: 70.3ms
# 10:	learn: 0.5308676	test: 0.5466943	best: 0.5466943 (10)	total: 57.7ms	remaining: 205ms
# 20:	learn: 0.4456804	test: 0.4903447	best: 0.4903447 (20)	total: 1.32s	remaining: 1.83s
# 30:	learn: 0.4001714	test: 0.4613272	best: 0.4613272 (30)	total: 1.7s	remaining: 1.04s
# 40:	learn: 0.3664568	test: 0.4427409	best: 0.4427409 (40)	total: 2.65s	remaining: 582ms
# 49:	learn: 0.3431507	test: 0.4347502	best: 0.4347502 (49)	total: 2.99s	remaining: 0us
#
# bestTest = 0.4347502113
# bestIteration = 49
#
# 95:	loss: 0.4347502	best: 0.4160750 (29)	total: 35.1s	remaining: 1.46s
# 0:	learn: 0.6630940	test: 0.6647117	best: 0.6647117 (0)	total: 1.43ms	remaining: 70.2ms
# 10:	learn: 0.4628001	test: 0.4987130	best: 0.4987130 (10)	total: 322ms	remaining: 1.14s
# 20:	learn: 0.3800203	test: 0.4465075	best: 0.4465075 (20)	total: 1.09s	remaining: 1.51s
# 30:	learn: 0.3316968	test: 0.4295470	best: 0.4295470 (30)	total: 2.05s	remaining: 1.26s
# 40:	learn: 0.3047323	test: 0.4278291	best: 0.4275919 (39)	total: 3.25s	remaining: 713ms
# 49:	learn: 0.2845845	test: 0.4303882	best: 0.4275919 (39)	total: 4.94s	remaining: 0us
#
# bestTest = 0.4275918772
# bestIteration = 39
#
# 96:	loss: 0.4275919	best: 0.4160750 (29)	total: 40s	remaining: 1.24s
# 0:	learn: 0.6352911	test: 0.6385973	best: 0.6385973 (0)	total: 2.93ms	remaining: 143ms
# 10:	learn: 0.3663525	test: 0.4427455	best: 0.4427455 (10)	total: 687ms	remaining: 2.44s
# 20:	learn: 0.2966225	test: 0.4389802	best: 0.4354822 (14)	total: 1.09s	remaining: 1.51s
# 30:	learn: 0.2644952	test: 0.4475432	best: 0.4354822 (14)	total: 2.02s	remaining: 1.24s
# 40:	learn: 0.2240662	test: 0.4619608	best: 0.4354822 (14)	total: 4.64s	remaining: 1.02s
# 49:	learn: 0.2034765	test: 0.4672354	best: 0.4354822 (14)	total: 5.19s	remaining: 0us
#
# bestTest = 0.4354821673
# bestIteration = 14
#
# 97:	loss: 0.4354822	best: 0.4160750 (29)	total: 45.2s	remaining: 923ms
# 0:	learn: 0.5863222	test: 0.5931833	best: 0.5931833 (0)	total: 2.5ms	remaining: 122ms
# 10:	learn: 0.2930474	test: 0.4365028	best: 0.4361813 (8)	total: 1.6s	remaining: 5.66s
# 20:	learn: 0.2281587	test: 0.4566405	best: 0.4361813 (8)	total: 3.32s	remaining: 4.59s
# 30:	learn: 0.1693035	test: 0.4842064	best: 0.4361813 (8)	total: 6.34s	remaining: 3.88s
# 40:	learn: 0.1223813	test: 0.4980941	best: 0.4361813 (8)	total: 10.1s	remaining: 2.21s
# 49:	learn: 0.0932889	test: 0.5125273	best: 0.4361813 (8)	total: 13.4s	remaining: 0us
#
# bestTest = 0.4361813108
# bestIteration = 8
#
# 98:	loss: 0.4361813	best: 0.4160750 (29)	total: 58.6s	remaining: 592ms
# 0:	learn: 0.4868875	test: 0.5059755	best: 0.5059755 (0)	total: 1.94ms	remaining: 94.8ms
# 10:	learn: 0.1787135	test: 0.4883578	best: 0.4514902 (2)	total: 1.88s	remaining: 6.68s
# 20:	learn: 0.0848142	test: 0.5091264	best: 0.4514902 (2)	total: 5.7s	remaining: 7.87s
# 30:	learn: 0.0435030	test: 0.5452053	best: 0.4514902 (2)	total: 11.1s	remaining: 6.8s
# 40:	learn: 0.0307298	test: 0.5900066	best: 0.4514902 (2)	total: 16.5s	remaining: 3.61s
# 49:	learn: 0.0254054	test: 0.6115456	best: 0.4514902 (2)	total: 20.5s	remaining: 0us
#
# bestTest = 0.451490244
# bestIteration = 2
#
# 99:	loss: 0.4514902	best: 0.4160750 (29)	total: 1m 19s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
# 0:	learn: 0.4694492	test: 0.5042863	best: 0.5042863 (0)	total: 3.27ms	remaining: 13.1ms
# 4:	learn: 0.3338031	test: 0.4646200	best: 0.4594139 (3)	total: 13.9ms	remaining: 0us
#
# bestTest = 0.4594139453
# bestIteration = 3
#
# Training on fold [1/3]
# 0:	learn: 0.5114540	test: 0.4805467	best: 0.4805467 (0)	total: 1.73ms	remaining: 6.91ms
# 4:	learn: 0.3792798	test: 0.3847773	best: 0.3847773 (4)	total: 8.58ms	remaining: 0us
#
# bestTest = 0.384777262
# bestIteration = 4
#
# Training on fold [2/3]
# 0:	learn: 0.5409240	test: 0.5524621	best: 0.5524621 (0)	total: 1.53ms	remaining: 6.14ms
# 4:	learn: 0.3391943	test: 0.4560411	best: 0.4427243 (2)	total: 6.76ms	remaining: 0us
#
# bestTest = 0.4427242504
# bestIteration = 2

# %%
print(" Results from Grid Search " )
grid_search_result
# Out:
#  Results from Grid Search
# {'params': {'depth': 6, 'iterations': 5, 'learning_rate': 0.5},
#  'cv_results': defaultdict(list,
#              {'iterations': [0, 1, 2, 3, 4],
#               'test-Logloss-mean': [0.5124317205760773,
#                0.4479984382657025,
#                0.44102604165847525,
#                0.43284013491376955,
#                0.4351461224699709],
#               'test-Logloss-std': [0.03664306399347675,
#                0.03110707557634716,
#                0.031112682033890223,
#                0.03743399862821907,
#                0.04383111040978316],
#               'train-Logloss-mean': [0.5072757415440918,
#                0.41724834217442774,
#                0.3848318346318349,
#                0.3649348590389138,
#                0.35075907903545867],
#               'train-Logloss-std': [0.035920131191357466,
#                0.029508250195289736,
#                0.034270168888837306,
#                0.027745607665575198,
#                0.024846321291792386]})}

# %%
grid_search_result['params']
# Out:
# {'depth': 6, 'iterations': 5, 'learning_rate': 0.5}

# %%
cat_index = [X_scaled.columns.get_loc(i) for i in ["Sex","Embarked","Title","Deck"]]

# %%
model = CatBoostClassifier(iterations=5, learning_rate=0.5, depth=6, verbose=10)

# %%
# %%time
model.fit(X_train, y_train, cat_index)
# Out:
# 0:	learn: 0.5540404	total: 27.2ms	remaining: 109ms
# 4:	learn: 0.4097471	total: 91.3ms	remaining: 0us
# Wall time: 119 ms

# %%
# %%time
y_pred = model.predict(X_test)
# Out:
# Wall time: 1e+03 µs

# %%
# %%time
# Get predicted probabilities for each class
preds_proba = model.predict_proba(X_test)
preds_proba
# Out:
# Wall time: 3 ms
# array([[0.64921265, 0.35078735],
#        [0.76741484, 0.23258516],
#        [0.87623192, 0.12376808],
#        [0.15922443, 0.84077557],
#        [0.65240068, 0.34759932],
#        [0.64921265, 0.35078735],
#        [0.74495495, 0.25504505],
#        [0.880843  , 0.119157  ],
#        [0.43885265, 0.56114735],
#        [0.71916572, 0.28083428],
#        [0.5384267 , 0.4615733 ],
#        [0.73105891, 0.26894109],
#        [0.31475641, 0.68524359],
#        [0.1295311 , 0.8704689 ],
#        [0.83931759, 0.16068241],
#        [0.69168568, 0.30831432],
#        [0.46990063, 0.53009937],
#        [0.87464224, 0.12535776],
#        [0.67463575, 0.32536425],
#        [0.09716733, 0.90283267],
#        [0.71943452, 0.28056548],
#        [0.58422182, 0.41577818],
#        [0.1045621 , 0.8954379 ],
#        [0.71095944, 0.28904056],
#        [0.8164503 , 0.1835497 ],
#        [0.43885265, 0.56114735],
#        [0.880843  , 0.119157  ],
#        [0.880843  , 0.119157  ],
#        [0.880843  , 0.119157  ],
#        [0.880843  , 0.119157  ],
#        [0.67156646, 0.32843354],
#        [0.61596352, 0.38403648],
#        [0.68155158, 0.31844842],
#        [0.61355125, 0.38644875],
#        [0.734128  , 0.265872  ],
#        [0.09264728, 0.90735272],
#        [0.3749797 , 0.6250203 ],
#        [0.7967495 , 0.2032505 ],
#        [0.09264728, 0.90735272],
#        [0.18822656, 0.81177344],
#        [0.87623192, 0.12376808],
#        [0.65199534, 0.34800466],
#        [0.78387973, 0.21612027],
#        [0.74114296, 0.25885704],
#        [0.880843  , 0.119157  ],
#        [0.13106881, 0.86893119],
#        [0.52980598, 0.47019402],
#        [0.78387973, 0.21612027],
#        [0.20201008, 0.79798992],
#        [0.41448037, 0.58551963],
#        [0.72818982, 0.27181018],
#        [0.36988809, 0.63011191],
#        [0.87623192, 0.12376808],
#        [0.65240068, 0.34759932],
#        [0.5300263 , 0.4699737 ],
#        [0.6489219 , 0.3510781 ],
#        [0.31475641, 0.68524359],
#        [0.74495495, 0.25504505],
#        [0.880843  , 0.119157  ],
#        [0.8435065 , 0.1564935 ],
#        [0.880843  , 0.119157  ],
#        [0.69671106, 0.30328894],
#        [0.41448037, 0.58551963],
#        [0.41448037, 0.58551963],
#        [0.59944177, 0.40055823],
#        [0.83931759, 0.16068241],
#        [0.78637252, 0.21362748],
#        [0.80791069, 0.19208931],
#        [0.72060773, 0.27939227],
#        [0.29829084, 0.70170916],
#        [0.87623192, 0.12376808],
#        [0.15549129, 0.84450871],
#        [0.61297123, 0.38702877],
#        [0.13796262, 0.86203738],
#        [0.87464224, 0.12535776],
#        [0.15720483, 0.84279517],
#        [0.87464224, 0.12535776],
#        [0.17343927, 0.82656073],
#        [0.880843  , 0.119157  ],
#        [0.37936107, 0.62063893],
#        [0.880843  , 0.119157  ],
#        [0.17504503, 0.82495497],
#        [0.880843  , 0.119157  ],
#        [0.87623192, 0.12376808],
#        [0.39450129, 0.60549871],
#        [0.69671106, 0.30328894],
#        [0.83931759, 0.16068241],
#        [0.41448037, 0.58551963],
#        [0.7591701 , 0.2408299 ],
#        [0.74114296, 0.25885704],
#        [0.41448037, 0.58551963],
#        [0.44230864, 0.55769136],
#        [0.41448037, 0.58551963],
#        [0.86395283, 0.13604717],
#        [0.2364209 , 0.7635791 ],
#        [0.74131824, 0.25868176],
#        [0.80791069, 0.19208931],
#        [0.11521395, 0.88478605],
#        [0.50514872, 0.49485128],
#        [0.86854624, 0.13145376],
#        [0.74495495, 0.25504505],
#        [0.79177071, 0.20822929],
#        [0.5286497 , 0.4713503 ],
#        [0.87623192, 0.12376808],
#        [0.41188223, 0.58811777],
#        [0.31475641, 0.68524359],
#        [0.7034538 , 0.2965462 ],
#        [0.880843  , 0.119157  ],
#        [0.18018856, 0.81981144],
#        [0.87623192, 0.12376808],
#        [0.71943452, 0.28056548],
#        [0.73105891, 0.26894109],
#        [0.880843  , 0.119157  ],
#        [0.87464224, 0.12535776],
#        [0.71943452, 0.28056548],
#        [0.87464224, 0.12535776],
#        [0.14873982, 0.85126018],
#        [0.87464224, 0.12535776],
#        [0.87464224, 0.12535776],
#        [0.65199534, 0.34800466],
#        [0.28004821, 0.71995179],
#        [0.19959982, 0.80040018],
#        [0.83466839, 0.16533161],
#        [0.24551095, 0.75448905],
#        [0.29829084, 0.70170916],
#        [0.78207062, 0.21792938],
#        [0.41448037, 0.58551963],
#        [0.41448037, 0.58551963],
#        [0.65199534, 0.34800466],
#        [0.87464224, 0.12535776],
#        [0.66357914, 0.33642086],
#        [0.77105646, 0.22894354],
#        [0.70136501, 0.29863499],
#        [0.880843  , 0.119157  ],
#        [0.10127452, 0.89872548],
#        [0.31475641, 0.68524359],
#        [0.70583916, 0.29416084],
#        [0.87623192, 0.12376808],
#        [0.14819878, 0.85180122],
#        [0.29829084, 0.70170916],
#        [0.15922443, 0.84077557],
#        [0.58292607, 0.41707393],
#        [0.62273719, 0.37726281],
#        [0.8435065 , 0.1564935 ],
#        [0.79910006, 0.20089994],
#        [0.87623192, 0.12376808],
#        [0.880843  , 0.119157  ],
#        [0.31475641, 0.68524359],
#        [0.24110466, 0.75889534],
#        [0.77923365, 0.22076635],
#        [0.880843  , 0.119157  ],
#        [0.25912862, 0.74087138],
#        [0.83931759, 0.16068241],
#        [0.41448037, 0.58551963],
#        [0.13437767, 0.86562233],
#        [0.66162885, 0.33837115],
#        [0.75242277, 0.24757723],
#        [0.880843  , 0.119157  ],
#        [0.10127452, 0.89872548],
#        [0.880843  , 0.119157  ],
#        [0.6370369 , 0.3629631 ],
#        [0.73747469, 0.26252531],
#        [0.880843  , 0.119157  ],
#        [0.70136501, 0.29863499],
#        [0.87464224, 0.12535776],
#        [0.880843  , 0.119157  ],
#        [0.41448037, 0.58551963],
#        [0.80791069, 0.19208931],
#        [0.87623192, 0.12376808],
#        [0.67587422, 0.32412578],
#        [0.18179527, 0.81820473],
#        [0.15922443, 0.84077557],
#        [0.6362041 , 0.3637959 ],
#        [0.10163615, 0.89836385],
#        [0.77849861, 0.22150139],
#        [0.64802637, 0.35197363],
#        [0.47312023, 0.52687977],
#        [0.87623192, 0.12376808],
#        [0.75856397, 0.24143603],
#        [0.87623192, 0.12376808],
#        [0.31475641, 0.68524359],
#        [0.74061556, 0.25938444],
#        [0.76368293, 0.23631707],
#        [0.31475641, 0.68524359],
#        [0.76368293, 0.23631707],
#        [0.880843  , 0.119157  ],
#        [0.14819878, 0.85180122],
#        [0.87623192, 0.12376808],
#        [0.87134277, 0.12865723],
#        [0.12227889, 0.87772111],
#        [0.71916572, 0.28083428],
#        [0.7302044 , 0.2697956 ],
#        [0.3612978 , 0.6387022 ],
#        [0.880843  , 0.119157  ],
#        [0.31475641, 0.68524359],
#        [0.29829084, 0.70170916],
#        [0.880843  , 0.119157  ],
#        [0.71943452, 0.28056548],
#        [0.42395026, 0.57604974],
#        [0.7591701 , 0.2408299 ],
#        [0.65199534, 0.34800466],
#        [0.31475641, 0.68524359],
#        [0.86854624, 0.13145376],
#        [0.87623192, 0.12376808],
#        [0.41448037, 0.58551963],
#        [0.10222391, 0.89777609],
#        [0.69671106, 0.30328894],
#        [0.68593558, 0.31406442],
#        [0.24551095, 0.75448905],
#        [0.64791814, 0.35208186],
#        [0.14010611, 0.85989389],
#        [0.69671106, 0.30328894],
#        [0.67156646, 0.32843354],
#        [0.75608258, 0.24391742],
#        [0.10185967, 0.89814033],
#        [0.72986385, 0.27013615],
#        [0.1228883 , 0.8771117 ],
#        [0.86854624, 0.13145376],
#        [0.87623192, 0.12376808],
#        [0.7302044 , 0.2697956 ],
#        [0.29829084, 0.70170916],
#        [0.87464224, 0.12535776],
#        [0.14695857, 0.85304143],
#        [0.69369761, 0.30630239],
#        [0.54311304, 0.45688696],
#        [0.82861811, 0.17138189],
#        [0.87464224, 0.12535776],
#        [0.12219879, 0.87780121],
#        [0.87464224, 0.12535776],
#        [0.86565724, 0.13434276],
#        [0.8435065 , 0.1564935 ],
#        [0.87623192, 0.12376808],
#        [0.21183985, 0.78816015],
#        [0.60673308, 0.39326692],
#        [0.87623192, 0.12376808],
#        [0.87464224, 0.12535776],
#        [0.10185967, 0.89814033],
#        [0.72108809, 0.27891191],
#        [0.880843  , 0.119157  ],
#        [0.16115211, 0.83884789],
#        [0.36177972, 0.63822028],
#        [0.41448037, 0.58551963],
#        [0.82861811, 0.17138189],
#        [0.78327459, 0.21672541],
#        [0.880843  , 0.119157  ],
#        [0.86854624, 0.13145376],
#        [0.87464224, 0.12535776],
#        [0.87464224, 0.12535776],
#        [0.6140527 , 0.3859473 ],
#        [0.69371333, 0.30628667],
#        [0.86565724, 0.13434276],
#        [0.69343472, 0.30656528],
#        [0.10185967, 0.89814033],
#        [0.19745304, 0.80254696],
#        [0.87623192, 0.12376808],
#        [0.20201008, 0.79798992],
#        [0.59944177, 0.40055823],
#        [0.880843  , 0.119157  ],
#        [0.81378676, 0.18621324],
#        [0.87623192, 0.12376808],
#        [0.83931759, 0.16068241],
#        [0.29829084, 0.70170916],
#        [0.8435065 , 0.1564935 ],
#        [0.29829084, 0.70170916],
#        [0.62263785, 0.37736215],
#        [0.55786117, 0.44213883],
#        [0.39450129, 0.60549871],
#        [0.43885265, 0.56114735],
#        [0.63540188, 0.36459812],
#        [0.1295311 , 0.8704689 ],
#        [0.15922443, 0.84077557],
#        [0.87464224, 0.12535776],
#        [0.7967495 , 0.2032505 ],
#        [0.73825319, 0.26174681],
#        [0.31475641, 0.68524359],
#        [0.68558713, 0.31441287],
#        [0.66803116, 0.33196884],
#        [0.41448037, 0.58551963],
#        [0.841364  , 0.158636  ],
#        [0.59842426, 0.40157574],
#        [0.1558127 , 0.8441873 ],
#        [0.77722954, 0.22277046],
#        [0.52268468, 0.47731532],
#        [0.11161645, 0.88838355],
#        [0.54311304, 0.45688696],
#        [0.41448037, 0.58551963],
#        [0.11161645, 0.88838355],
#        [0.880843  , 0.119157  ],
#        [0.8435065 , 0.1564935 ],
#        [0.87623192, 0.12376808],
#        [0.87464224, 0.12535776],
#        [0.79910006, 0.20089994],
#        [0.11161645, 0.88838355],
#        [0.17504503, 0.82495497]])

# %%
# %%time
# Get predicted RawFormulaVal
preds_raw = model.predict(X_test, prediction_type='RawFormulaVal')
# Out:
# Wall time: 2.92 ms

# %%
# %%time
# evaluate predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: %.2f%%" % (accuracy * 100.0))
print("Precision: %.2f%%" % (precision * 100.0))
print("Recall: %.2f%%" % (recall * 100.0))
# Out:
# Accuracy: 81.29%
# Precision: 82.83%
# Recall: 68.33%
# Wall time: 3.93 ms

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[157,  17],
#        [ 38,  82]], dtype=int64)

# %%
color = 'black'
matrix = plot_confusion_matrix(model, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix', color=color)
plt.xlabel('Predicted Label', color=color)
plt.ylabel('True Label', color=color)
plt.gcf().axes[0].tick_params(colors=color)
plt.gcf().axes[1].tick_params(colors=color)
plt.show()

# %% [markdown]
# #### Predict phase

# %%
model = CatBoostClassifier(iterations=5, learning_rate=0.5, depth=6, verbose=10)
model.fit(X_scaled, Y, cat_index)
# Out:
# 0:	learn: 0.5498123	total: 14.9ms	remaining: 59.7ms
# 4:	learn: 0.4182784	total: 71.6ms	remaining: 0us

# %% [markdown]
# - Preparing test data:

# %%
test['PassengerId'] = test['PassengerId'].apply(str)
test.dropna(subset='Embarked', inplace=True)
test['Cabin'].fillna('Unknown', inplace = True)
test.loc[test['Age'] <1, 'Age'] = 0
test['Age'].fillna(0, inplace = True)
temp = test['Name'].apply(lambda x: x.split(','))
test['LastName'] = temp.apply(lambda x: x[0])
temp = temp.apply(lambda x: x[1].split('.'))
test['FirstName'] = temp.apply(lambda x: x[1][1:])
test['Title'] = temp.apply(lambda x: x[0][1:])
test.drop(columns=['Name'], inplace = True)
test['Title']= test.apply(replace_titles, axis=1)
cabin_list = ['A', 'B', 'C', 'D', 'E', 'F', 'T', 'G', 'Unknown']
test['Deck']=test['Cabin'].map(lambda x: substrings_in_string(x, cabin_list))
test['FamilySize']=test['SibSp']+test['Parch']
test.drop(columns=['Parch', 'SibSp', 'Cabin', 'LastName', 'FirstName', 'Ticket'], inplace=True)
test.head(3)
test['Age'] = test['Age'].apply(int)
test.set_index('PassengerId', inplace=True)

# %%
# Plot test distribution
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
sns.distplot(test['Age'], color=(0.188,0.66,0.413))

plt.subplot(1,2,2)
sns.distplot(test['Fare'], color=(0.5,0,0.8))
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
test_log = test.copy()
test_log['Age'] = test_log['Age'].map(lambda i: np.log(i) if i > 0 else 0)
test_log['Fare'] = test_log['Fare'].map(lambda i: np.log(i) if i > 0 else 0)

plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
sns.distplot(test_log['Age'], color=(0.188,0.66,0.413))

plt.subplot(1,2,2)
sns.distplot(test_log['Fare'], color=(0.5,0,0.8))
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
scaler = StandardScaler()
test_scaled = scaler.fit_transform(test[["Age","Fare","FamilySize", "Pclass"]])
test_scaled = pd.DataFrame(test_scaled,columns=["Age","Fare","FamilySize","Pclass"], index=test.index)
test_scaled = test_scaled.join(test.drop(columns=["Age","Fare","FamilySize","Pclass"]))

# %%
# reorder column in case that they dont match with train set
test_scaled = test_scaled[X_scaled.columns]

# %%
result = pd.DataFrame(model.predict(test_scaled), index=test_scaled.index, columns=['Survived']).reset_index()

# %%
result['Survived'].value_counts()
# Out:
# 0    254
# 1    164
# Name: Survived, dtype: int64

# %%
result.to_csv("result.csv",index=False)

# %% [markdown]
# ### 2.3.2. XGBOOST

# %%
X_scaled_enc = X_scaled.drop(columns=['Sex','Embarked', 'Title', 'Deck']).copy()
for i in ['Sex','Embarked', 'Title', 'Deck']:
    s = pd.get_dummies(X_scaled[i])
    X_scaled_enc = X_scaled_enc.merge(s, on='PassengerId', how='inner')

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X_scaled_enc, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier()

model = XGBClassifier(max_depth =20, eta= 0.0001, objective= 'binary:logistic',nthread= 4)
model.fit(X_train, y_train, eval_metric='auc')
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False, eta=0.0001,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=9.99999975e-05,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=20, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=4, nthread=4, num_parallel_tree=1, ...)

# %%
# %%time
y_pred = model.predict(X_test)
# Out:
# Wall time: 3.83 ms

# %%
# %%time
# evaluate predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy: %.2f%%" % (accuracy * 100.0))
print("Precision: %.2f%%" % (precision * 100.0))
print("Recall: %.2f%%" % (recall * 100.0))
# Out:
# Accuracy: 81.29%
# Precision: 77.31%
# Recall: 76.67%
# Wall time: 3.07 ms

# %%
color = 'black'
matrix = plot_confusion_matrix(model, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix', color=color)
plt.xlabel('Predicted Label', color=color)
plt.ylabel('True Label', color=color)
plt.gcf().axes[0].tick_params(colors=color)
plt.gcf().axes[1].tick_params(colors=color)
plt.show()

# %% [markdown]
# #### Predict phase

# %%
X_test_scaled_enc = test_scaled.drop(columns=['Sex','Embarked', 'Title', 'Deck']).copy()
for i in ['Sex','Embarked', 'Title', 'Deck']:
    s = pd.get_dummies(test_scaled[i])
    X_test_scaled_enc = X_test_scaled_enc.merge(s, on='PassengerId', how='inner')

# %%
a = np.intersect1d(X_test_scaled_enc.columns, X_scaled_enc.columns)
b = list(set(X_scaled_enc).difference(X_test_scaled_enc))
X_test_scaled_enc_filter = X_test_scaled_enc[a]
X_test_scaled_enc_filter[b]=0
X_test_scaled_enc_filter=X_test_scaled_enc_filter[X_scaled_enc.columns]

# %%
# %%time
model.fit(X_scaled_enc, Y, eval_metric='auc')
result_xgb = pd.DataFrame(model.predict(X_test_scaled_enc_filter), index=X_test_scaled_enc_filter.index, columns=['Survived']).reset_index()
# Out:
# Wall time: 128 ms

# %%
result_xgb['Survived'].value_counts()
# Out:
# 0    254
# 1    164
# Name: Survived, dtype: int64

# %%
result_xgb.to_csv("result_xgb.csv",index=False)
